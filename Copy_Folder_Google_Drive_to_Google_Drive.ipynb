# %% [markdown]
# <a href="https://colab.research.google.com/github/toandz0820/TLB/blob/main/Copy_Folder_Google_Drive_to_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Copy Folder Google Drive to Google Drive - 1TouchPro

# %%
#@title Input
from ipywidgets import widgets

dest_text = widgets.Text(description="Your drive", placeholder='Nhập đường link folder Google Drive của bạn')
source_text = widgets.Text(description="Shared drive", placeholder='Nhập đường link folder Google Drive shared')
from_page_text = widgets.Text(description="Từ trang", value="0")
to_page_text = widgets.Text(description="Đến trang", value="0")
max_download_size_text = widgets.Text(description="Tổng dung lượng tối đa(GB)", value="700")
exclude_str_text = widgets.Text(description="Bỏ file, folder có chứa nội dung", value="")

display(dest_text)
display(source_text)
display(from_page_text)
display(to_page_text)
display(max_download_size_text)
display(exclude_str_text)
# Out:
# Text(value='', description='Your drive', placeholder='Nhập đường link folder Google Drive của bạn')
# Text(value='', description='Shared drive', placeholder='Nhập đường link folder Google Drive shared')
# Text(value='0', description='Từ trang')
# Text(value='0', description='Đến trang')
# Text(value='700', description='Tổng dung lượng tối đa(GB)')
# Text(value='', description='Bỏ file, folder có chứa nội dung')

# %%
#@title Run
import os
import time
import re
import sys
from googleapiclient.discovery import build
from google.colab import auth
from google.colab import drive

class DownloadFromDrive:
    def __init__(self):
        self._total_size = 0
        self._limit_size = 0
        self.excluded_strings = []

    def get_user_credential(self):
        auth.authenticate_user()
        drive_service = build('drive', 'v3')
        return drive_service

    def get_childs_from_folder(self, drive_service, folder_id, from_page, to_page):
        files = []
        page_token = None
        query = f"'{folder_id}' in parents and trashed = false"
        if self.excluded_strings and len(self.excluded_strings) > 0:
            not_contains_query = " and ".join([f"not name contains '{ext}'" for ext in self.excluded_strings])
            query += f" and ({not_contains_query})"

        pages = 0
        while True:
            try:
                pages += 1
                response = drive_service.files().list(q=query,
                                        orderBy='name, createdTime',
                                        fields='files(id, name, mimeType, size), nextPageToken',
                                        pageToken=page_token,
                                        supportsAllDrives=True,
                                        includeItemsFromAllDrives=True).execute()

                if (from_page < pages <= to_page) or to_page == 0:
                    files.extend(response.get('files', []))

                page_token = response.get('nextPageToken', None)
                if page_token is None or  (pages >= to_page > 0):
                    break
            except Exception as e:
                print(f"An error occurred: {str(e)}")
                page_token = None

        print(f"Total files: {len(files)}")
        return files

    def copy_file(self, drive_service, dest_folder_id, source_file):
        if source_file['mimeType'] != 'application/vnd.google-apps.folder':
            body_file_inf = {'parents': [dest_folder_id]}

            if not self.check_if_exists(drive_service, dest_folder_id, source_file['name']):
                try:
                    start_time = time.time()
                    request_copy = drive_service.files().copy(body=body_file_inf, fileId=source_file['id'],
                                                              supportsAllDrives=True).execute()
                    end_time = time.time()

                    fileSize = int(source_file.get('size', 0))
                    size_mb = fileSize / (1024 * 1024)
                    self._total_size += size_mb
                    speed_mb = size_mb / (end_time - start_time)
                    print(f"[{source_file['name']}] copied. Size {size_mb:0.2f} MB. Speed {speed_mb:0.2f} MB/s")


                    if self._total_size >= (self._limit_size * 1024):
                        self.on_total_size_exceeded(f"Total size exceeds {self._limit_size} GB. Ending the program.")
                except Exception as e:
                    print("An error occurred: ", e)
            else:
                print(f"[{source_file['name']}] exists.")
        else:

            source_files = self.get_childs_from_folder(drive_service, source_file['id'], 0, 0)
            if source_files and len(source_files) > 0:
                print(f"Copy at Folder {source_file['name']} Starting")
                sub_folder_id = self.create_folder(drive_service, dest_folder_id, source_file['name'])
                self.copy_multiple_files(drive_service, sub_folder_id, source_files)
                print(f"Copy at Folder {source_file['name']} Ending")


    def create_folder(self, drive_service, dest_folder_id, sub_folder_name):
        sub_folder_inf = {'name': sub_folder_name, 'mimeType': 'application/vnd.google-apps.folder', 'parents': [dest_folder_id]}

        exist_folder_id = self.check_if_exists(drive_service, dest_folder_id, sub_folder_name)
        if not exist_folder_id:
            try:
                folder = drive_service.files().create(body=sub_folder_inf, fields='id').execute()
                return folder['id']
            except Exception as e:
                print("An error occurred: ", e)
        return exist_folder_id


    def check_if_exists(self, drive_service, dest_folder_id, name):
        try:
            processed_name = name.replace("'", "\\'")

            results = drive_service.files().list(q=f"'{dest_folder_id}' in parents and name contains '{processed_name}' and trashed=false",
                                                fields='files(id)').execute()

            if 'files' in results and len(results['files']) > 0:
                return results['files'][0]['id']
        except Exception as e:
            print("An error occurred: ", e)

        return ""


    def copy_multiple_files(self, drive_service, dest_folder_id, source_files):
        for source_file in source_files:
            self.copy_file(drive_service, dest_folder_id, source_file)

    def extract_folder_id_from_url(self, url):
        pattern = r'[-\w]{25,}'
        match = re.search(pattern, url)
        if match:
            return match.group(0)
        else:
            return None

    def on_total_size_exceeded(self, message):
        print(message)
        sys.exit()

    def copy_drive_to_drive(self, destDriveLink, sourceDriveLink, from_page, to_page):
        service = self.get_user_credential()

        start_time = time.time()
        dest_folder_id = self.extract_folder_id_from_url(destDriveLink)
        source_folder_id = self.extract_folder_id_from_url(sourceDriveLink)
        source_folder = service.files().get(fileId=source_folder_id, supportsAllDrives=True).execute()
        new_dest_folder_id = self.create_folder(service, dest_folder_id, source_folder['name'])

        source_files = self.get_childs_from_folder(service, source_folder_id, from_page, to_page)
        self.copy_multiple_files(service, new_dest_folder_id, source_files)
        end_time = time.time()

        size_gb = self._total_size / 1024
        speed_mb = self._total_size / (end_time - start_time)

        print(f"Done. Total Size {size_gb:0.2f} GB. Total Time {int(end_time - start_time)} s. SpeedMB {speed_mb:0.2f} MB/s")


# Main
destDriveLink = dest_text.value
sourceDriveLink = source_text.value
fromPage = int(from_page_text.value)
toPage = int(to_page_text.value)

downloader = DownloadFromDrive()
downloader._limit_size = float(max_download_size_text.value);
downloader.excluded_strings = [ext.strip() for ext in exclude_str_text.value.split(",") if ext.strip()]
downloader.copy_drive_to_drive(destDriveLink, sourceDriveLink, fromPage, toPage)
# Out:
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# Total files: 11
# Total files: 4
# Copy at Folder 1. Hướng dẫn khóa học Starting
# [Cách thêm sub vào video.url] copied. Size 0.00 MB. Speed 0.00 MB/s
# [Danh sách khóa học.url] copied. Size 0.00 MB. Speed 0.00 MB/s
# [Hướng dẫn cần chú ý khi sử dụng khóa học.txt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [LƯU Ý QUAN TRỌNG.txt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 1. Hướng dẫn khóa học Ending
# Total files: 3
# Copy at Folder 10. Bonus Starting
# Total files: 5
# Copy at Folder 7773 Khóa Học Thiết Kế PCB Với Altium Designer 22 Phiên Bản Mới Nhất Starting
# [Cách thêm sub vào video.url] copied. Size 0.00 MB. Speed 0.00 MB/s
# [Danh sách khóa học.url] copied. Size 0.00 MB. Speed 0.00 MB/s
# [Hướng dẫn cần chú ý khi sử dụng khóa học.txt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [LƯU Ý QUAN TRỌNG.txt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Total files: 1
# Copy at Folder PCB Design Altium Designer 22 Starting
# Total files: 15
# Copy at Folder PCB Design Altium Designer 22 Starting
# Total files: 2
# Copy at Folder 01 - Introduction Starting
# [001 Introduction.mp4] copied. Size 66.26 MB. Speed 44.76 MB/s
# [001 Introduction_en.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 01 - Introduction Ending
# Total files: 18
# Copy at Folder 02 - Schematic Design Part01 Starting
# [001 01.create project.mp4] copied. Size 59.57 MB. Speed 38.45 MB/s
# [001 01.create project_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [002 02.schematic propereties.mp4] copied. Size 62.11 MB. Speed 44.23 MB/s
# [002 02.schematic propereties_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [003 03.components.mp4] copied. Size 78.42 MB. Speed 55.01 MB/s
# [003 03.components_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [004 04.selection.mp4] copied. Size 47.06 MB. Speed 33.95 MB/s
# [004 04.selection_en.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [005 05.filters.mp4] copied. Size 32.26 MB. Speed 22.24 MB/s
# [005 05.filters_en.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [006 06.design schematic like pro.mp4] copied. Size 94.19 MB. Speed 71.62 MB/s
# [006 06.design schematic like pro_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [007 07.new way of doing documenting your schematic.mp4] copied. Size 64.56 MB. Speed 47.97 MB/s
# [007 07.new way of doing documenting your schematic_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [008 08.Component properties.mp4] copied. Size 45.14 MB. Speed 32.97 MB/s
# [008 08.Component properties_en.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [009 09.Read document of a component.mp4] copied. Size 50.16 MB. Speed 40.73 MB/s
# [009 09.Read document of a component_en.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# Copy at Folder 02 - Schematic Design Part01 Ending
# Total files: 6
# Copy at Folder 03 - Custom schematic component library Starting
# [001 10.create component libriry.mp4] copied. Size 42.16 MB. Speed 29.29 MB/s
# [001 10.create component libriry_en.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [002 11.create schematic component.mp4] copied. Size 29.55 MB. Speed 22.66 MB/s
# [002 11.create schematic component_en.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [003 This section library.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# [40737662-mylib.IntLib] copied. Size 0.02 MB. Speed 0.02 MB/s
# Copy at Folder 03 - Custom schematic component library Ending
# Total files: 2
# Copy at Folder 04 - Schematic Design part02 Starting
# [001 12.design power supply with our part.mp4] copied. Size 117.47 MB. Speed 94.49 MB/s
# [001 12.design power supply with our part_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# Copy at Folder 04 - Schematic Design part02 Ending
# Total files: 6
# Copy at Folder 05 - Custom PCB component library (footprint) Starting
# [001 13.create pcb footprint part one top overlay.mp4] copied. Size 125.02 MB. Speed 86.68 MB/s
# [001 13.create pcb footprint part one top overlay_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [002 14.create pads and placing them.mp4] copied. Size 119.68 MB. Speed 93.00 MB/s
# [002 14.create pads and placing them_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [003 15.connect footprint of the component with schematic component.mp4] copied. Size 91.95 MB. Speed 67.81 MB/s
# [003 15.connect footprint of the component with schematic component_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# Copy at Folder 05 - Custom PCB component library (footprint) Ending
# Total files: 2
# Copy at Folder 06 - Anottation Starting
# [001 16.annotating designators.mp4] copied. Size 59.24 MB. Speed 48.03 MB/s
# [001 16.annotating designators_en.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# Copy at Folder 06 - Anottation Ending
# Total files: 12
# Copy at Folder 07 - PCB Design part01 Starting
# [001 17.create pcb board and change its size.mp4] copied. Size 73.80 MB. Speed 59.42 MB/s
# [001 17.create pcb board and change its size_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [002 18.add schematic component to our pcb project.mp4] copied. Size 60.30 MB. Speed 43.55 MB/s
# [002 18.add schematic component to our pcb project_en.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [003 19.some tricks of placing component on pcb.mp4] copied. Size 201.30 MB. Speed 112.78 MB/s
# [003 19.some tricks of placing component on pcb_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [004 20. component alignment.mp4] copied. Size 134.50 MB. Speed 89.52 MB/s
# [004 20. component alignment_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [005 21.pads alignment.mp4] copied. Size 84.90 MB. Speed 62.87 MB/s
# [005 21.pads alignment_en.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [006 22.routing and routing rules.mp4] copied. Size 124.33 MB. Speed 91.77 MB/s
# [006 22.routing and routing rules_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# Copy at Folder 07 - PCB Design part01 Ending
# Total files: 2
# Copy at Folder 08 - Components on internet Starting
# [001 23.find component librarys in internet.mp4] copied. Size 157.69 MB. Speed 109.47 MB/s
# [001 23.find component librarys in internet_en.vtt] copied. Size 0.02 MB. Speed 0.01 MB/s
# Copy at Folder 08 - Components on internet Ending
# Total files: 16
# Copy at Folder 09 - Schematic Design part03 Starting
# [001 24.design multi sheet and lets add a mcu.mp4] copied. Size 127.09 MB. Speed 96.03 MB/s
# [001 24.design multi sheet and lets add a mcu_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [002 25.MCU power supply section.mp4] copied. Size 175.96 MB. Speed 130.70 MB/s
# [002 25.MCU power supply section_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [003 26.find 8MHz crystal for our mcu.mp4] copied. Size 107.12 MB. Speed 81.53 MB/s
# [003 26.find 8MHz crystal for our mcu_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [004 27.use net labels.mp4] copied. Size 82.00 MB. Speed 62.96 MB/s
# [004 27.use net labels_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [005 28.circuit of crystals and its capacitors.mp4] copied. Size 96.45 MB. Speed 79.78 MB/s
# [005 28.circuit of crystals and its capacitors_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [006 29.reset pin of mcu.mp4] copied. Size 63.71 MB. Speed 48.30 MB/s
# [006 29.reset pin of mcu_en.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [007 30.boot options.mp4] copied. Size 61.31 MB. Speed 46.69 MB/s
# [007 30.boot options_en.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [008 31.debug section of mcu.mp4] copied. Size 83.20 MB. Speed 60.94 MB/s
# [008 31.debug section of mcu_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# Copy at Folder 09 - Schematic Design part03 Ending
# Total files: 20
# Copy at Folder 10 - PCB Design Part02 Starting
# [001 32.update pcb with our mcu.mp4] copied. Size 62.52 MB. Speed 48.79 MB/s
# [001 32.update pcb with our mcu_en.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [002 33.most important design rules.mp4] copied. Size 71.20 MB. Speed 55.96 MB/s
# [002 33.most important design rules_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [003 34.bypass cap placement.mp4] copied. Size 80.85 MB. Speed 63.50 MB/s
# [003 34.bypass cap placement_en.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [004 35.advance rules.mp4] copied. Size 255.61 MB. Speed 182.65 MB/s
# [004 35.advance rules_en.vtt] copied. Size 0.02 MB. Speed 0.01 MB/s
# [005 36.place reset cap and reset tac switch.mp4] copied. Size 83.57 MB. Speed 59.54 MB/s
# [005 36.place reset cap and reset tac switch_en.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [006 37.routing crystals.mp4] copied. Size 158.54 MB. Speed 113.23 MB/s
# [006 37.routing crystals_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [007 38.vias and vias rules.mp4] copied. Size 106.11 MB. Speed 77.39 MB/s
# [007 38.vias and vias rules_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [008 39.multilayer design.mp4] copied. Size 196.68 MB. Speed 150.54 MB/s
# [008 39.multilayer design_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [009 40.Rooms.mp4] copied. Size 127.75 MB. Speed 90.64 MB/s
# [009 40.Rooms_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [010 41.measurment and dimensions.mp4] copied. Size 122.81 MB. Speed 94.56 MB/s
# [010 41.measurment and dimensions_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# Copy at Folder 10 - PCB Design Part02 Ending
# Total files: 8
# Copy at Folder 11 - 3D body Starting
# [001 42.add simple 3d body and pro 3d body.mp4] copied. Size 179.91 MB. Speed 130.86 MB/s
# [001 42.add simple 3d body and pro 3d body_en.vtt] copied. Size 0.02 MB. Speed 0.01 MB/s
# [002 43.3d body for mcu.mp4] copied. Size 67.81 MB. Speed 53.75 MB/s
# [002 43.3d body for mcu_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [003 44.3d body better way.mp4] copied. Size 32.54 MB. Speed 26.26 MB/s
# [003 44.3d body better way_en.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [004 Library for all component that we used in this course.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# [40737730-smartmcu.IntLib] copied. Size 1.64 MB. Speed 1.14 MB/s
# Copy at Folder 11 - 3D body Ending
# Total files: 26
# Copy at Folder 12 - PCB Design part03 Starting
# [001 45.align all top and bottom overlays.mp4] copied. Size 102.99 MB. Speed 77.46 MB/s
# [001 45.align all top and bottom overlays_en.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [002 46.add led indiation.mp4] copied. Size 85.72 MB. Speed 68.82 MB/s
# [002 46.add led indiation_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [003 My tested library.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# [004 47.add pin headers for all the gpio.mp4] copied. Size 129.93 MB. Speed 106.67 MB/s
# [004 47.add pin headers for all the gpio_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [005 48.place all pull up and pull downs.mp4] copied. Size 105.40 MB. Speed 80.63 MB/s
# [005 48.place all pull up and pull downs_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [006 49.connect gpio by pcb.mp4] copied. Size 165.09 MB. Speed 120.32 MB/s
# [006 49.connect gpio by pcb_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [007 50.best way to connect gpio.mp4] copied. Size 35.85 MB. Speed 31.72 MB/s
# [007 50.best way to connect gpio_en.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [008 51.pushing routes.mp4] copied. Size 66.32 MB. Speed 53.76 MB/s
# [008 51.pushing routes_en.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [009 52.use copy paste better.mp4] copied. Size 106.57 MB. Speed 88.72 MB/s
# [009 52.use copy paste better_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [010 53.guidance for our pcb.mp4] copied. Size 172.10 MB. Speed 137.24 MB/s
# [010 53.guidance for our pcb_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [011 54.use solid mode for better selecting.mp4] copied. Size 50.66 MB. Speed 42.01 MB/s
# [011 54.use solid mode for better selecting_en.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [012 55.bill of material.mp4] copied. Size 69.48 MB. Speed 52.22 MB/s
# [012 55.bill of material_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [013 56.polygons.mp4] copied. Size 131.29 MB. Speed 96.91 MB/s
# [013 56.polygons_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [40737810-Mylib-Rev-4.IntLib] copied. Size 50.83 MB. Speed 41.85 MB/s
# Copy at Folder 12 - PCB Design part03 Ending
# Total files: 6
# Copy at Folder 13 - Manufacturing Starting
# [001 57.gerber files for manufacturer.mp4] copied. Size 33.71 MB. Speed 27.99 MB/s
# [001 57.gerber files for manufacturer_en.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [002 58.Tips and tricks part 01.mp4] copied. Size 59.75 MB. Speed 48.96 MB/s
# [002 58.Tips and tricks part 01_en.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [003 59.design rule check.mp4] copied. Size 150.42 MB. Speed 124.12 MB/s
# [003 59.design rule check_en.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# Copy at Folder 13 - Manufacturing Ending
# Total files: 4
# Copy at Folder 14 - All the library Starting
# [001 all the library that i used in this lecture.html] copied. Size 0.00 MB. Speed 0.00 MB/s
#
MB/s
# [Đáp án Reading.pdf] copied. Size 0.17 MB. Speed 0.13 MB/s
# [Đề Listening.pdf] copied. Size 9.68 MB. Speed 8.00 MB/s
# [Đề Reading.pdf] copied. Size 19.90 MB. Speed 16.02 MB/s
# Copy at Folder Test 5 Ending
# Total files: 7
# Copy at Folder Test 6 Starting
# [AUDIO.mp3] copied. Size 41.82 MB. Speed 33.42 MB/s
# [Lời giải Listening.pdf] copied. Size 5.62 MB. Speed 4.83 MB/s
# [Lời giải Reading.pdf] copied. Size 0.63 MB. Speed 0.47 MB/s
# [Đáp án Listening.pdf] copied. Size 0.16 MB. Speed 0.14 MB/s
# [Đáp án Reading.pdf] copied. Size 0.17 MB. Speed 0.14 MB/s
# [Đề Listening.pdf] copied. Size 9.48 MB. Speed 7.84 MB/s
# [Đề Reading.pdf] copied. Size 20.04 MB. Speed 17.61 MB/s
# Copy at Folder Test 6 Ending
# Total files: 7
# Copy at Folder Test 7 Starting
# [AUDIO.mp3] copied. Size 41.72 MB. Speed 34.90 MB/s
# [Lời giải Listening.pdf] copied. Size 4.68 MB. Speed 3.80 MB/s
# [Lời giải Reading.pdf] copied. Size 0.64 MB. Speed 0.52 MB/s
# [Đáp án Listening.pdf] copied. Size 0.16 MB. Speed 0.14 MB/s
# [Đáp án Reading.pdf] copied. Size 0.17 MB. Speed 0.15 MB/s
# [Đề Listening.pdf] copied. Size 9.44 MB. Speed 6.76 MB/s
# [Đề Reading.pdf] copied. Size 19.45 MB. Speed 13.88 MB/s
# Copy at Folder Test 7 Ending
# Total files: 7
# Copy at Folder Test 8 Starting
# [AUDIO.mp3] copied. Size 42.07 MB. Speed 34.32 MB/s
# [Lời giải Listening.pdf] copied. Size 4.79 MB. Speed 4.02 MB/s
# [Lời giải Reading.pdf] copied. Size 0.60 MB. Speed 0.51 MB/s
# [Đáp án Listening.pdf] copied. Size 0.16 MB. Speed 0.12 MB/s
# [Đáp án Reading.pdf] copied. Size 0.17 MB. Speed 0.14 MB/s
# [Đề Listening.pdf] copied. Size 9.54 MB. Speed 7.35 MB/s
# [Đề Reading.pdf] copied. Size 19.46 MB. Speed 16.03 MB/s
# Copy at Folder Test 8 Ending
# Total files: 7
# Copy at Folder Test 9 Starting
# [AUDIO.mp3] copied. Size 42.34 MB. Speed 33.94 MB/s
# [Lời giải Listening.pdf] copied. Size 4.46 MB. Speed 3.56 MB/s
# [Lời giải Reading.pdf] copied. Size 0.62 MB. Speed 0.46 MB/s
# [Đáp án Listening.pdf] copied. Size 0.16 MB. Speed 0.12 MB/s
# [Đáp án Reading.pdf] copied. Size 0.17 MB. Speed 0.13 MB/s
# [Đề Listening.pdf] copied. Size 9.85 MB. Speed 8.14 MB/s
# [Đề Reading.pdf] copied. Size 19.64 MB. Speed 15.50 MB/s
# Copy at Folder Test 9 Ending
# Copy at Folder Đề ETS 2024 Ending
# Copy at Folder BỘ ĐỀ ETS 2019-2024 Ending
# Copy at Folder 11. Tặng kèm Khóa học TOIEC Ending
# Total files: 2
# Copy at Folder 2. Lộ trình cho người mới bắt đầu Starting
# [Lộ trình học cho người mới bắt đầu] copied. Size 0.00 MB. Speed 0.00 MB/s
# [README.txt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 2. Lộ trình cho người mới bắt đầu Ending
# Total files: 19
# Copy at Folder 3. Arduino Starting
# Total files: 1
# Copy at Folder 7146 Khóa Học Hệ Thống Nhúng Nâng Cao Với Arduino [Update Tháng 6-2023] Starting
# Total files: 1
# Copy at Folder NSTH-Embedded.Systems.Arduino Starting
# Total files: 31
# Copy at Folder NSTH-Embedded.Systems.Arduino Starting
# Total files: 2
# Copy at Folder 1. Introduction Starting
# [1. Introduction.mp4] copied. Size 39.85 MB. Speed 32.29 MB/s
# [1. Introduction.srt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 1. Introduction Ending
# Total files: 4
# Copy at Folder 10. LCD Interfacing Starting
# [1. LCD Chapter 1.mp4] copied. Size 44.93 MB. Speed 36.61 MB/s
# [1. LCD Chapter 1.srt] copied. Size 0.02 MB. Speed 0.01 MB/s
# [2. LCD Chapter 2.mp4] copied. Size 59.80 MB. Speed 46.01 MB/s
# [2. LCD Chapter 2.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# Copy at Folder 10. LCD Interfacing Ending
# Total files: 2
# Copy at Folder 11. Keypad Starting
# [1. Concepts around keypad.mp4] copied. Size 78.63 MB. Speed 62.80 MB/s
# [1. Concepts around keypad.srt] copied. Size 0.02 MB. Speed 0.01 MB/s
# Copy at Folder 11. Keypad Ending
# Total files: 10
# Copy at Folder 12. Analog Input Starting
# [1. Analog To Digital Converter Graph And Formula.mp4] copied. Size 34.05 MB. Speed 26.54 MB/s
# [1. Analog To Digital Converter Graph And Formula.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [2. ADC Resolution And Voltage Conversion In Detail.mp4] copied. Size 19.57 MB. Speed 14.96 MB/s
# [2. ADC Resolution And Voltage Conversion In Detail.srt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [3. Analog To Digital Converter Chapter 3.mp4] copied. Size 51.85 MB. Speed 38.60 MB/s
# [3. Analog To Digital Converter Chapter 3.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [4. Analog To Digital Converter Chapter 4.mp4] exists.
# [4. Analog To Digital Converter Chapter 4.srt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [5. Analog To Digital Converter Chapter 5.mp4] copied. Size 18.67 MB. Speed 14.75 MB/s
# ...
# [1. What is Boot-Loader and Why it is needed .vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# Copy at Folder 2. Introduction Ending
# Total files: 4
# Copy at Folder 20. Implementing  BL_MEM_WRITE_CMD Starting
# [1. BL_MEM_WRITE Commadn Implementation.mp4] copied. Size 161.58 MB. Speed 130.35 MB/s
# [1. BL_MEM_WRITE Commadn Implementation.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [2. BL_MEM_WRITE Command Testing.mp4] copied. Size 70.18 MB. Speed 56.14 MB/s
# [2. BL_MEM_WRITE Command Testing.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# Copy at Folder 20. Implementing  BL_MEM_WRITE_CMD Ending
# Total files: 6
# Copy at Folder 21. Options Bytes and Flash Sector Protection Starting
# [1. Options Bytes Programming.mp4] copied. Size 216.84 MB. Speed 164.03 MB/s
# [1. Options Bytes Programming.vtt] copied. Size 0.02 MB. Speed 0.01 MB/s
# [2. Implementing Flash Sector Protection Commands.mp4] copied. Size 178.23 MB. Speed 133.52 MB/s
# [2. Implementing Flash Sector Protection Commands.vtt] copied. Size 0.02 MB. Speed 0.01 MB/s
# [3. Summary of the commands.mp4] copied. Size 45.18 MB. Speed 32.52 MB/s
# [3. Summary of the commands.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 21. Options Bytes and Flash Sector Protection Ending
# Total files: 4
# Copy at Folder 22. Exploring HOST Application Starting
# [1. HOST application Source files and Details.mp4] copied. Size 79.27 MB. Speed 63.19 MB/s
# [1. HOST application Source files and Details.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [2. Procedure to Add your own command.mp4] copied. Size 157.11 MB. Speed 115.96 MB/s
# [2. Procedure to Add your own command.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# Copy at Folder 22. Exploring HOST Application Ending
# Total files: 1
# Copy at Folder 23. BONUS LECTURE Starting
# [1. BONUS LECTURE.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 23. BONUS LECTURE Ending
# Total files: 6
# Copy at Folder 3. MCU memory, Reset Sequence and Boot configs Starting
# [1. MCU-Embedded Memory Organization.mp4] copied. Size 65.61 MB. Speed 53.42 MB/s
# [1. MCU-Embedded Memory Organization.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [2. Understanding Reset Sequence and memory Aliasing of the MCU.mp4] copied. Size 86.24 MB. Speed 69.87 MB/s
# [2. Understanding Reset Sequence and memory Aliasing of the MCU.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [3. Boot Configurations of the STM32 MCU..mp4] copied. Size 72.47 MB. Speed 59.49 MB/s
# [3. Boot Configurations of the STM32 MCU..vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# Copy at Folder 3. MCU memory, Reset Sequence and Boot configs Ending
# Total files: 9
# Copy at Folder 4. Development board used in our courses Starting
# [1. Note for the students.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# [2. About MCU Development board.mp4] copied. Size 52.15 MB. Speed 41.07 MB/s
# [2. About MCU Development board.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [3. STM32F4 Discovery and Nucleo  Board Details.mp4] copied. Size 121.16 MB. Speed 98.55 MB/s
# [3. STM32F4 Discovery and Nucleo  Board Details.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [4. ST-Link Driver Installation.mp4] copied. Size 32.30 MB. Speed 24.42 MB/s
# [4. ST-Link Driver Installation.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [5. ST Link Firmware Upgrade.mp4] copied. Size 32.33 MB. Speed 25.73 MB/s
# [5. ST Link Firmware Upgrade.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 4. Development board used in our courses Ending
# Total files: 15
# Copy at Folder 5. KEIL-MDK-5 IDE setup for ARM Cortex M based MCUs Starting
# [1. Note for the students.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# [2. KEIL-MDK-5 Installation.mp4] copied. Size 95.69 MB. Speed 69.09 MB/s
# [2. KEIL-MDK-5 Installation.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [3. KEIL-MDK-5 Installation Contd..mp4] copied. Size 29.33 MB. Speed 17.42 MB/s
# [3. KEIL-MDK-5 Installation Contd..vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [4. KEIL-MDK-5 Pack Installation.mp4] copied. Size 187.55 MB. Speed 150.84 MB/s
# [4. KEIL-MDK-5 Pack Installation.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [5. Locating Pack Installation files.mp4] copied. Size 29.98 MB. Speed 23.41 MB/s
# [5. Locating Pack Installation files.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [6. Creating a KEIL Project.mp4] copied. Size 123.78 MB. Speed 88.92 MB/s
# [6. Creating a KEIL Project.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [7. Creating a LED Toggling App using Board BSP APIs.mp4] copied. Size 207.09 MB. Speed 155.16 MB/s
# [7. Creating a LED Toggling App using Board BSP APIs.vtt] copied. Size 0.02 MB. Speed 0.01 MB/s
# [8. Creating a LED Toggling App using Board BSP APIs-Nucleo.mp4] copied. Size 57.68 MB. Speed 43.75 MB/s
# [8. Creating a LED Toggling App using Board BSP APIs-Nucleo.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# Copy at Folder 5. KEIL-MDK-5 IDE setup for ARM Cortex M based MCUs Ending
# Total files: 4
# Copy at Folder 6. Installing OpenSTM32  System-Workbench Starting
# [1. Downloading and Installing OpenSTM32  System-Workbench.mp4] copied. Size 81.87 MB. Speed 68.16 MB/s
# [1. Downloading and Installing OpenSTM32  System-Workbench.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [2. Installing OpenSTM32  System-Workbench.mp4] copied. Size 41.77 MB. Speed 34.41 MB/s
# [2. Installing OpenSTM32  System-Workbench.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# Copy at Folder 6. Installing OpenSTM32  System-Workbench Ending
# Total files: 3
# Copy at Folder 7. STM32CubeMX Starting
# [1. Note for the students.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# [2. STM32CubeMX Installation.mp4] copied. Size 44.49 MB. Speed 34.58 MB/s
# [2. STM32CubeMX Installation.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 7. STM32CubeMX Ending
# Total files: 10
# Copy at Folder 8. Exploring STM32 Native Bootloader Starting
# [1. Activating ST’s Bootloader Part-1.mp4] copied. Size 58.63 MB. Speed 47.58 MB/s
# [1. Activating ST’s Bootloader Part-1.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [2. Activating ST’s Bootloader Part-2.mp4] copied. Size 39.85 MB. Speed 33.96 MB/s
# [2. Activating ST’s Bootloader Part-2.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [3. Activating ST’s Bootloader Part-3.mp4] copied. Size 70.77 MB. Speed 57.53 MB/s
# [3. Activating ST’s Bootloader Part-3.vtt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [3.1 STM32 Flash Loader.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# [4. Activating ST’s Bootloader Part-4.mp4] exists.
# [4. Activating ST’s Bootloader Part-4.vtt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [4.1 blinky.zip.zip] copied. Size 0.54 MB. Speed 0.48 MB/s
# Copy at Folder 8. Exploring STM32 Native Bootloader Ending
# Total files: 9
# Copy at Folder 9. Custom Bootloader Communication with HOST Starting
# [1. Bootloader Transport.mp4] copied. Size 11.64 MB. Speed 9.52 MB/s
# [1. Bootloader Transport.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [2. Bootloader code placement.mp4] copied. Size 10.87 MB. Speed 9.00 MB/s
# [2. Bootloader code placement.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [3. Bootloader Supported Commands.mp4] copied. Size 38.90 MB. Speed 29.08 MB/s
# [3. Bootloader Supported Commands.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [3.1 Commands Documents and PPT.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# [4. Host – Bootloader Communication.mp4] copied. Size 19.67 MB. Speed 14.40 MB/s
# [4. Host – Bootloader Communication.vtt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 9. Custom Bootloader Communication with HOST Ending
# Copy at Folder STM32Fx Microcontroller Bootloader Ending
# Copy at Folder STM32Fx Microcontroller Bootloader Ending
# Copy at Folder 8146 Khóa Học STM32Fx Microcontroller Custom Bootloader Development Ending
# Total files: 15
# Copy at Folder 8162 Khóa Học Lập Trình Hệ Thống Nhúng Bare-Metal (STM32) Starting
# Total files: 17
# Copy at Folder 1. Getting Started - Constructing Peripheral Registers from Memory Addresses Starting
# [1. Downloading our Integrated Development Environment (IDE).mp4] copied. Size 16.14 MB. Speed 12.24 MB/s
# [1. Downloading our Integrated Development Environment (IDE).srt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [2. Installing our Integrated Development Environment (IDE).mp4] copied. Size 13.07 MB. Speed 9.68 MB/s
# [2. Installing our Integrated Development Environment (IDE).srt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [3. Getting the right Documentation for Bare-Metal Development.mp4] copied. Size 40.01 MB. Speed 31.96 MB/s
# [3. Getting the right Documentation for Bare-Metal Development.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [4. Coding  Locating the Ports and Pins of Components on the Nucleo board.mp4] copied. Size 46.67 MB. Speed 35.89 MB/s
# [4. Coding  Locating the Ports and Pins of Components on the Nucleo board.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [5. Coding  Defining Addresses of Modules using information from the Documentation.mp4] copied. Size 122.27 MB. Speed 103.52 MB/s
# [5. Coding  Defining Addresses of Modules using information from the Documentation.srt] copied. Size 0.02 MB. Speed 0.02 MB/s
# [6. Coding  Creating required Registers using Information from Documentation.mp4] copied. Size 125.81 MB. Speed 87.07 MB/s
# [6. Coding  Creating required Registers using Information from Documentation.srt] copied. Size 0.02 MB. Speed 0.02 MB/s
# [7. Coding   Configuring Pins using the Registers we Created.mp4] copied. Size 52.84 MB. Speed 41.24 MB/s
# [7. Coding   Configuring Pins using the Registers we Created.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [8. Coding  Creating Registers from Structure Members.mp4] copied. Size 173.22 MB. Speed 101.24 MB/s
# [8. Coding  Creating Registers from Structure Members.srt] copied. Size 0.02 MB. Speed 0.02 MB/s
# [9. Notice.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 1. Getting Started - Constructing Peripheral Registers from Memory Addresses Ending
# Total files: 4
# Copy at Folder 1_simple_spi_write Starting
# [1_simple_spi_write.uvguix.Israel] copied. Size 0.09 MB. Speed 0.07 MB/s
# [1_simple_spi_write.uvoptx] copied. Size 0.01 MB. Speed 0.01 MB/s
# [1_simple_spi_write.uvprojx] copied. Size 0.02 MB. Speed 0.01 MB/s
# [main.c] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 1_simple_spi_write Ending
# Total files: 10
# Copy at Folder 1_spi_st7735_driver Starting
# [Abstract.txt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [adc.c] copied. Size 0.00 MB. Speed 0.00 MB/s
# [adc.h] copied. Size 0.00 MB. Speed 0.00 MB/s
# [EventRecorderStub.scvd] copied. Size 0.00 MB. Speed 0.00 MB/s
# [GLCD_ST7735.c] copied. Size 0.01 MB. Speed 0.01 MB/s
# [GLCD_ST7735.h] copied. Size 0.01 MB. Speed 0.01 MB/s
# [main.c] copied. Size 0.00 MB. Speed 0.00 MB/s
# [ST7735_driver.uvguix.Israel] copied. Size 0.09 MB. Speed 0.07 MB/s
# [ST7735_driver.uvoptx] copied. Size 0.01 MB. Speed 0.01 MB/s
# [ST7735_driver.uvprojx] copied. Size 0.02 MB. Speed 0.02 MB/s
# Copy at Folder 1_spi_st7735_driver Ending
# Total files: 1
# Copy at Folder _stm32 Starting
# [RTE_Components.h] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder _stm32 Ending
# Total files: 1
# Copy at Folder _stm32f4 Starting
# [RTE_Components.h] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder _stm32f4 Ending
# Total files: 2
# Copy at Folder _Target_1 Starting
# [RTE_Components(1).h] copied. Size 0.00 MB. Speed 0.00 MB/s
# [RTE_Components.h] exists.
# Copy at Folder _Target_1 Ending
# Total files: 4
# Copy at Folder DebugConfig Starting
# [stm32_STM32F411VETx.dbgconf] copied. Size 0.00 MB. Speed 0.00 MB/s
# [stm32f4_STM32F411VETx.dbgconf] copied. Size 0.00 MB. Speed 0.00 MB/s
# [Target_1_STM32F411VETx.dbgconf] copied. Size 0.00 MB. Speed 0.00 MB/s
# [Target_1_STM32F411VETx.dbgconf(1)] exists.
# Copy at Folder DebugConfig Ending
# Total files: 0
# Total files: 0
# Total files: 1
# Copy at Folder Embedded Systems Bare Metal STM32 Starting
# Total files: 24
# Copy at Folder Embedded Systems Bare Metal STM32 Starting
# Total files: 14
# Copy at Folder 10. Serial Peripheral Interface (SPI) Starting
# [1. Introduction to Serial Peripheral Interface (SPI).mp4] copied. Size 141.44 MB. Speed 114.49 MB/s
# [1. Introduction to Serial Peripheral Interface (SPI).srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [2. Coding   Implementing the SPI GPIO Initialization function.mp4] copied. Size 76.21 MB. Speed 65.08 MB/s
# [2. Coding   Implementing the SPI GPIO Initialization function.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [3. Coding  Configuring the SPI Parameters.mp4] copied. Size 85.67 MB. Speed 62.87 MB/s
# [3. Coding  Configuring the SPI Parameters.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [4. Coding  Implementing the SPI Transmit.mp4] copied. Size 55.93 MB. Speed 43.23 MB/s
# [4. Coding  Implementing the SPI Transmit.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [5. Coding  Implementing the SPI Receive.mp4] copied. Size 44.39 MB. Speed 33.53 MB/s
# [5. Coding  Implementing the SPI Receive.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [6. Coding  Configuring the ADXL345 Accelerometer using the SPI Driver.mp4] copied. Size 101.91 MB. Speed 83.19 MB/s
# [6. Coding  Configuring the ADXL345 Accelerometer using the SPI Driver.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [7. Coding  Testing our ADXL345 Driver.mp4] copied. Size 20.63 MB. Speed 15.86 MB/s
# [7. Coding  Testing our ADXL345 Driver.srt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 10. Serial Peripheral Interface (SPI) Ending
# Total files: 2
# Copy at Folder 11. Start of Old Version of the Course - Introduction Starting
# [1. Introduction.mp4] copied. Size 25.08 MB. Speed 19.11 MB/s
# [1. Introduction.srt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 11. Start of Old Version of the Course - Introduction Ending
# Total files: 9
# Copy at Folder 12. Set Up Starting
# [1. Download Keil uVision 5.mp4] copied. Size 9.94 MB. Speed 7.91 MB/s
# [1. Download Keil uVision 5.srt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [2. Installing Keil uVision 5.mp4] copied. Size 9.47 MB. Speed 7.65 MB/s
# [2. Installing Keil uVision 5.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [3. Notice.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# [4. Installing Packs.mp4] copied. Size 44.94 MB. Speed 39.09 MB/s
# [4. Installing Packs.srt] copied. Size 0.01 MB. Speed 0.00 MB/s
# [5. Changing the Compiler.mp4] copied. Size 6.36 MB. Speed 4.73 MB/s
# [5. Changing the Compiler.srt] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 12. Set Up Ending
# Total files: 11
# Copy at Folder 13. General Purpose InputOutput(GPIO) Starting
# [1. Overview of ARM Cortex-M General Purpose InputOutput Module.mp4] copied. Size 33.15 MB. Speed 27.55 MB/s
# [1. Overview of ARM Cortex-M General Purpose InputOutput Module.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [2. Coding  Developing GPIO Driver Using Information from the Datasheet.mp4] copied. Size 421.89 MB. Speed 360.97 MB/s
# [2. Coding  Developing GPIO Driver Using Information from the Datasheet.srt] copied. Size 0.06 MB. Speed 0.05 MB/s
# [3. Understanding the BSRR Register.mp4] copied. Size 15.90 MB. Speed 12.78 MB/s
# [3. Understanding the BSRR Register.srt] copied. Size 0.00 MB. Speed 0.00 MB/s
# [4. Coding  Controlling GPIO using the BSRR Register.mp4] copied. Size 142.65 MB. Speed 113.32 MB/s
# [4. Coding  Controlling GPIO using the BSRR Register.srt] copied. Size 0.02 MB. Speed 0.01 MB/s
# [5. Coding  Reading GPIO Inputs.mp4] copied. Size 66.72 MB. Speed 51.62 MB/s
# [5. Coding  Reading GPIO Inputs.srt] copied. Size 0.01 MB. Speed 0.01 MB/s
# [6. Notice.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# Copy at Folder 13. General Purpose InputOutput(GPIO) Ending
# Total files: 5
# Copy at Folder 14. Writing Bare-Metal C Code with STM32CubeIDE Starting
# [1. Notice.html] copied. Size 0.00 MB. Speed 0.00 MB/s
# [2. Coding  Writing a GPIO Driver from Scratch (PART I).mp4] copied. Size 193.53 MB. Speed 151.02 MB/s
# [2. Coding  Writing a GPIO Driver from Scratch (PART I).srt] copied. Size 0.05 MB. Speed 0.03 MB/s
# [3. Coding  Writing a GPIO Driver from Scratch (PART II).mp4] copied. Size 119.28 MB. Speed 90.84 MB/s
# [3. Coding  Writing a GPIO Driver from Scratch (PART II).srt] copied. Size 0.02 MB. Speed 0.02 MB/s
# Copy at Folder 14. Writing Bare-Metal C Code with STM32CubeIDE Ending
# Total files: 12
# Copy at Folder 15. Universal Asynchronous Receiver-Transmitter(UART) Starting
